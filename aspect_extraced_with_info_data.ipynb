# %% [markdown]
# <a href="https://colab.research.google.com/github/VellummyilumVinoth/Aspect_based_sentimental_analysis/blob/main/aspect_extraced_with_info_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
dataset = pd.read_csv('/content/drive/MyDrive/zidan/aspect_sentiments.csv')

# %%
columns_to_drop = ['Price', 'Packaging', 'Delivery Cost', 'Quality','Usability','Customer Service','Design','Overall Sentiment']
dataset.drop(columns_to_drop, axis=1, inplace=True)

# %%
dataset.head(10)
# Out:
#                          Product_name  \
# 0  Sunlight Care Detergent Liquid, 1L
# 1  Sunlight Care Detergent Liquid, 1L
# 2  Sunlight Care Detergent Liquid, 1L
# 3  Sunlight Care Detergent Liquid, 1L
# 4  Sunlight Care Detergent Liquid, 1L
# 5  Sunlight Care Detergent Liquid, 1L
# 6  Sunlight Care Detergent Liquid, 1L
# 7  Sunlight Care Detergent Liquid, 1L
# 8  Sunlight Care Detergent Liquid, 1L
# 9  Sunlight Care Detergent Liquid, 1L
#
#                                               Review  Overall Sentiment Score
# 0  I purchased 2 bottles. Both seem partially use...                        3
# 1  Very fast & safe delivery . Neet packing. I wi...                        0
# 2  Fast delivery during this pandemic. Got the pr...                        0
# 3  Alot of liquid has leaked.im very much disappo...                        0
# 4  Thank you very much !! I received my package t...                        0
# 5  Fast Delivery Delivered within One Day Well Pa...                        1
# 6  As many have complained here. it was leaking w...                        1
# 7  3/4 filled bottle. had spilled some out of the...                        2
# 8  Very good but some liquid leaking. Please pack...                        0
# 9  Nice packing....fast delivery....highly recomm...                        1

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import random

# Generate random reviewer names
def generate_reviewer_names(num_reviewers):
    first_names = ["John", "Jane", "Michael", "Emily", "David", "Olivia", "Daniel", "Sophia", "Matthew", "Emma", "Zidan", "Thinesh", "Albert", "Vinoth", "Saini", "Karthi"]
    last_names = ["Smith", "Johnson", "Brown", "Taylor", "Anderson", "Williams", "Jones", "Davis", "Miller", "Wilson", "Maryam", "Soosai", "Christopher","Vithujan", "Kumar", "Bathri"]
    reviewer_names = []
    for _ in range(num_reviewers):
        first_name = random.choice(first_names)
        last_name = random.choice(last_names)
        reviewer_names.append(f"{last_name} {first_name}")
    return reviewer_names

# Number of reviewers to generate
num_reviewers = 500

# Generate reviewer information
reviewer_names = generate_reviewer_names(num_reviewers)
reviewer_ages = np.random.randint(low=18, high=76, size=num_reviewers)
reviewer_genders = np.random.choice(["Male", "Female"], size=num_reviewers)
reviewer_areas = np.random.choice(["Central", "Eastern", "Northern", "North Central", "North Western", "Sabaragamuwa", "Southern", "Uva", "Western"], size=num_reviewers)

# Create a dictionary to map reviewer names with their respective age, gender, and area
reviewer_info = {name: (age, gender, area) for name, age, gender, area in zip(reviewer_names, reviewer_ages, reviewer_genders, reviewer_areas)}

# Assign random reviewer names to each row in the dataset
dataset['reviewer_name'] = random.choices(reviewer_names, k=len(dataset))

# Assign reviewer age, gender, and area based on the reviewer name
dataset['age'], dataset['gender'], dataset['area'] = zip(*[reviewer_info[name] for name in dataset['reviewer_name']])

# Extract the features
reviews = dataset["Review"]
product_names = dataset["Product_name"]
overall_sentiment_score = dataset["Overall Sentiment Score"]
reviewer_name = dataset["reviewer_name"]
age = dataset["age"]
gender = dataset["gender"]
area = dataset["area"]

# %%
dataset
# Out:
#                                            Product_name  \
# 0                    Sunlight Care Detergent Liquid, 1L
# 1                    Sunlight Care Detergent Liquid, 1L
# 2                    Sunlight Care Detergent Liquid, 1L
# 3                    Sunlight Care Detergent Liquid, 1L
# 4                    Sunlight Care Detergent Liquid, 1L
# ...                                                 ...
# 1837  Sustagen Nutritional Supplement Chocolate Flav...
# 1838  Sustagen Nutritional Supplement Chocolate Flav...
# 1839  Sustagen Nutritional Supplement Chocolate Flav...
# 1840  Sustagen Nutritional Supplement Chocolate Flav...
# 1841  Sustagen Nutritional Supplement Chocolate Flav...
#
#                                                  Review  \
# 0     I purchased 2 bottles. Both seem partially use...
# 1     Very fast & safe delivery . Neet packing. I wi...
# 2     Fast delivery during this pandemic. Got the pr...
# 3     Alot of liquid has leaked.im very much disappo...
# 4     Thank you very much !! I received my package t...
# ...                                                 ...
# 1837              very good product value for the price
# 1838  Delivery within 1day to Tangalle... well packe...
# 1839                      high quality reasonable price
# 1840  Excellent packaging. And it was delivered quic...
# 1841  It's not regarding product. all the canisters ...
#
#       Overall Sentiment Score     reviewer_name  age  gender           area
# 0                           3  Williams Thinesh   58  Female        Western
# 1                           0     Anderson John   46    Male       Southern
# 2                           0     Miller Sophia   38  Female        Western
# 3                           0    Maryam Michael   19    Male  North Central
# 4                           0     Johnson Emily   66  Female  North Western
# ...                       ...               ...  ...     ...            ...
# 1837                        0        Smith Jane   43    Male   Sabaragamuwa
# 1838                        0       Kumar Saini   32  Female        Central
# 1839                        2      Soosai Emily   51    Male       Southern
# 1840                        0     Bathri Daniel   25    Male  North Western
# 1841                        4      Soosai David   58    Male        Western
#
# [1842 rows x 7 columns]

# %%
# Save the updated dataset
dataset.to_csv('/content/drive/MyDrive/zidan/aspect_extracted_file_info.csv', index=False)
